# %%
#importing necessary lib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Titanic-Dataset.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.shape       #to view no of rows and columns in a dataset
# Out:
# (891, 12)

# %%
data.head()     #to view top 5 rows of a data
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()               #to summarize the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# **HANDLING NULL VALUES**

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age'].fillna(data['Age'].mean(),inplace=True)

# %%
data.drop('Cabin',axis=1,inplace=True)

# %%
data['Embarked'].fillna(method='ffill',inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# **HANDLING DUPLICATES VALUES**

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Age']=data['Age'].astype('int64')    #changing age datatype object to int

# %%
data.rename(columns={'Pclass':'passenger_class'},inplace=True)             #renaming the col_name

# %%
data['passenger_class'] = data['passenger_class'].replace({1: 'First Class', 2: 'Second Class', 3: 'Third Class'})

# %%
data['passenger_class']=data['passenger_class'].astype('object')    #changing passenger_class datatype int to object

# %%
data.head()
# Out:
#    PassengerId  Survived passenger_class  \
# 0            1         0     Third Class
# 1            2         1     First Class
# 2            3         1     Third Class
# 3            4         1     First Class
# 4            5         0     Third Class
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# **Exploratory Data Analysis**

# %%
survival_counts = data["Survived"].value_counts()
print(survival_counts)
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.figure(figsize = (4,5))
plt.pie(data["Survived"].value_counts(), 
        labels=["not survived", "survived"],
        autopct='%1.1f%%', 
        startangle=90,
       explode=[0, 0.1],
       shadow=True)

plt.title("Total number of Survived People")
plt.axis("equal")
plt.show()

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# Count the number of males and females
sex_counts = data['Sex'].value_counts()

# Create bar plot
plt.bar(sex_counts.index, sex_counts.values,color=['red','pink'],alpha=0.5)

# Labels and title
plt.xlabel("Sex")
plt.ylabel("Count")
plt.title("Count of Passengers by Gender")
plt.show()

# %%
x=data.groupby('Sex')['Survived'].sum().index
y=data.groupby('Sex')['Survived'].sum()

plt.figure(figsize=(5,4))
plt.title("Survival Count by Sex on the Titanic")

plt.bar(x,y,edgecolor="black")

plt.xlabel("Sex")
plt.ylabel("Survived")

plt.show()

# %%
x=data.groupby('Age')['Survived'].sum().index
y=data.groupby('Age')['Survived'].sum()
plt.figure(figsize=(6,4))
plt.title("Survival Rate Across Different Age Groups")

plt.bar(x,y,edgecolor="black")

plt.xlabel("Age")
plt.ylabel("Survived")

plt.show()

# %%
# number of survived along with the passenger_class
plt.figure(figsize = (6,4))
sns.countplot(data = data, x = data["passenger_class"], hue = data["Survived"])
plt.title("survival rate based on Passenger_class")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Embarked", hue="Survived", data=data)
plt.title("Survival by Embarkation Port")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(numeric_only=True), annot=True, fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
#adding col of age_group in dataset
# Define a function to categorize the age
def age_group(age):
    if age <= 12:
        return 'Child'
    elif age <= 19:
        return 'Teen'
    elif age <= 59:
        return 'Adult'
    else:
        return 'Senior'

# Apply the function to create the 'AgeGroup' column
data['AgeGroup'] = data['Age'].apply(age_group)

# %%
# Plot Survival Rate by Age Group
plt.figure(figsize=(6, 4))
sns.countplot(x='AgeGroup', hue='Survived', data=data)
plt.title("Survival Rate by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.show()

# %%
data.to_csv("titanic_cleaned.csv", index=False)                  #SAVING CLEAN DATA INTO CSV
